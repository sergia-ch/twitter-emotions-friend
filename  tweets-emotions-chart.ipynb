# %% [markdown]
# <a href="https://colab.research.google.com/github/sergia-ch/twitter-emotions-friend/blob/main/%20tweets-emotions-chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
curl 'https://twitter.com/i/api/graphql/UlRJ6hFoPvmZAwlQ_IrbhQ/UserTweets?variables=%7B%22userId%22%3A%221971455317%22%2C%22count%22%3A40%2C%22cursor%22%3A%22HCaAgIDYu8mo5icAAA%3D%3D%22%2C%22withTweetQuoteCount%22%3Atrue%2C%22includePromotedContent%22%3Atrue%2C%22withSuperFollowsUserFields%22%3Afalse%2C%22withUserResults%22%3Atrue%2C%22withBirdwatchPivots%22%3Afalse%2C%22withReactionsMetadata%22%3Afalse%2C%22withReactionsPerspective%22%3Afalse%2C%22withSuperFollowsTweetFields%22%3Afalse%2C%22withVoice%22%3Atrue%7D' -H 'User-Agent: Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:85.0) Gecko/20100101 Firefox/85.0' -H 'Accept: */*' -H 'Accept-Language: en-US,en;q=0.5' --compressed -H 'content-type: application/json' -H 'authorization: Bearer AAAAAAAAAAAAAAAAAAAAANRILgAAAAAAnNwIzUejRCOuH5E6I8xnZz4puTs%3D1Zv7ttfk8LF81IUq16cHjhLTvJu4FA33AGWWjCpTnA' -H 'x-guest-token: 1433922521452191744' -H 'x-twitter-client-language: en' -H 'x-twitter-active-user: yes' -H 'x-csrf-token: 75b2b5d761b7c8a6b577f07fe1d0d95f' -H 'DNT: 1' -H 'Connection: keep-alive' -H 'Referer: https://twitter.com/sergeivolodinch/' -H 'Cookie: personalization_id="v1_dBTeWQ07MLWbfOojvI7FyA=="; guest_id=v1%3A163070874473613613; gt=1433922521452191744; ct0=75b2b5d761b7c8a6b577f07fe1d0d95f' -H 'TE: Trailers'

# %% [markdown]
# cURL request:
#
# curl 'https://twitter.com/i/api/graphql/UlRJ6hFoPvmZAwlQ_IrbhQ/UserTweets?variables=%7B%22userId%22%3A%221971455317%22%2C%22count%22%3A40%2C%22cursor%22%3A%22HCaAgIDYu8mo5icAAA%3D%3D%22%2C%22withTweetQuoteCount%22%3Atrue%2C%22includePromotedContent%22%3Atrue%2C%22withSuperFollowsUserFields%22%3Afalse%2C%22withUserResults%22%3Atrue%2C%22withBirdwatchPivots%22%3Afalse%2C%22withReactionsMetadata%22%3Afalse%2C%22withReactionsPerspective%22%3Afalse%2C%22withSuperFollowsTweetFields%22%3Afalse%2C%22withVoice%22%3Atrue%7D' -H 'User-Agent: Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:85.0) Gecko/20100101 Firefox/85.0' -H 'Accept: */*' -H 'Accept-Language: en-US,en;q=0.5' --compressed -H 'content-type: application/json' -H 'authorization: Bearer AAAAAAAAAAAAAAAAAAAAANRILgAAAAAAnNwIzUejRCOuH5E6I8xnZz4puTs%3D1Zv7ttfk8LF81IUq16cHjhLTvJu4FA33AGWWjCpTnA' -H 'x-guest-token: 1433922521452191744' -H 'x-twitter-client-language: en' -H 'x-twitter-active-user: yes' -H 'x-csrf-token: 75b2b5d761b7c8a6b577f07fe1d0d95f' -H 'DNT: 1' -H 'Connection: keep-alive' -H 'Referer: https://twitter.com/sergeivolodinch/' -H 'Cookie: personalization_id="v1_dBTeWQ07MLWbfOojvI7FyA=="; guest_id=v1%3A163070874473613613; gt=1433922521452191744; ct0=75b2b5d761b7c8a6b577f07fe1d0d95f' -H 'TE: Trailers'

# %%
import requests
import json
from urllib.parse import quote

# %%
url = 'https://twitter.com/i/api/graphql/kXjqoWH8K51IsjfqEn5mRw/UserTweetsAndReplies'

request_variables = {
    "userId": "1971455317",
    "count": 20,
    "cursor": "HBaCwKKluLys3ScAAA==",
    "withTweetQuoteCount": True,
    "includePromotedContent": True,
    "withCommunity": False,
    "withSuperFollowsUserFields": False,
    "withUserResults": True,
    "withBirdwatchPivots": False,
    "withReactionsMetadata": False,
    "withReactionsPerspective": False,
    "withSuperFollowsTweetFields": False,
    "withVoice": True
}

headers = {
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:85.0) Gecko/20100101 Firefox/85.0',
    'Accept': '/',
    'Accept-Language': 'en-US,en;q=0.5',
    'content-type': 'application/json',
    'authorization': 'Bearer AAAAAAAAAAAAAAAAAAAAANRILgAAAAAAnNwIzUejRCOuH5E6I8xnZz4puTs%3D1Zv7ttfk8LF81IUq16cHjhLTvJu4FA33AGWWjCpTnA',
    'x-guest-token': '1433922521452191744',
    'x-twitter-client-language': 'en',
    'x-twitter-active-user': 'yes',
    # 'x-csrf-token': '75b2b5d761b7c8a6b577f07fe1d0d95f',
    'DNT': '1',
    'Connection': 'keep-alive',
    # 'Referer': 'https://twitter.com/sergeivolodinch/',
    # 'Cookie': 'personalization_id="v1_dBTeWQ07MLWbfOojvI7FyA=="; guest_id=v1%3A163070874473613613; gt=1433922521452191744; ct0=75b2b5d761b7c8a6b577f07fe1d0d95f',
    'TE': 'Trailers'
}

# %%
r = requests.get(url, params={'variables': json.dumps(request_variables)}, headers=headers)
r
# Out:
# <Response [200]>

# %%
r.json()
# Out:
# {'data': {'user': {'result': {'__typename': 'User',
#     'timeline': {'timeline': {'instructions': [{'entries': [{'content': {'entryType': 'TimelineTimelineItem',
#            'itemContent': {'itemType': 'TimelineTweet',
#             'tweetDisplayType': 'Tweet',
#             'tweet_results': {'result': {'__typename': 'Tweet',
#               'core': {'user_results': {'result': {'__typename': 'User',
#                  'affiliates_highlighted_label': {},
#                  'id': 'VXNlcjoxOTcxNDU1MzE3',
#                  'legacy': {'created_at': 'Sat Oct 19 12:11:47 +0000 2013',
#                   'default_profile': False,
#                   'default_profile_image': False,
#                   'description': 'Them. Want AI art. ex AI sfty🌻@TournesolApp, CS/Neurosci🇨🇭@EPFL_en, intern @CHAI_Berkeley, 🇺🇸@GoogleAI. Our op-s are not our own... From 🇷🇺 with ☮️❤️🌈.',
#                   'entities': {'description': {'urls': []},
#                    'url': {'urls': [{'display_url': 'sergia-ch.github.io',
#                       'expanded_url': 'https://sergia-ch.github.io',
#                       'indices': [0, 23],
#                       'url': 'https://t.co/IEhgwDqcb5'}]}},
#                   'fast_followers_count': 0,
#                   'favourites_count': 4548,
#                   'followers_count': 122,
#                   'friends_count': 1162,
#                   'has_custom_timelines': False,
#                   'is_translator': False,
#                   'listed_count': 0,
#                   'location': 'Confédération Helvétique',
#                   'media_count': 51,
#                   'name': 'Sergia',
#                   'normal_followers_count': 122,
#                   'pinned_tweet_ids_str': ['1429694898534559749'],
#                   'profile_banner_extensions': {'mediaColor': {'r': {'ok': {'palette': [{'percentage': 37.19,
#                         'rgb': {'blue': 90, 'green': 52, 'red': 47}},
#                        {'percentage': 31.4,
#                         'rgb': {'blue': 29, 'green': 24, 'red': 28}},
#                        {'percentage': 11.83,
#                         'rgb': {'blue': 171, 'green': 127, 'red': 133}},
#                        {'percentage': 8.12,
#                         'rgb': {'blue': 125, 'green': 114, 'red': 16}},
#                        {'percentage': 2.73,
#                         'rgb': {'blue': 190, 'green': 137, 'red': 36}}]}}}},
#                   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1971455317/1627655221',
#                   'profile_image_extensions': {'mediaColor': {'r': {'ok': {'palette': [{'percentage': 42.94,
#                         'rgb': {'blue': 17, 'green': 16, 'red': 22}},
#                        {'percentage': 34.25,
#                         'rgb': {'blue': 231, 'green': 247, 'red': 246}},
#                        {'percentage': 9.47,
#                         'rgb': {'blue': 95, 'green': 121, 'red': 160}},
#                        {'percentage': 4.58,
#                         'rgb': {'blue': 52, 'green': 38, 'red': 31}},
#                        {'percentage': 0.85,
#                         'rgb': {'blue': 165, 'green': 215, 'red': 243}}]}}}},
#                   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1429064209443196932/397bcCUf_normal.jpg',
#                   'profile_interstitial_type': '',
#                   'protected': False,
#                   'screen_name': 'sergeivolodinch',
#                   'statuses_count': 437,
#                   'translator_type': 'none',
#                   'url': 'https://t.co/IEhgwDqcb5',
#                   'verified': False,
#                   'withheld_in_countries': []},
#                  'rest_id': '1971455317'}}},
#               'legacy': {'conversation_id_str': '1431187998486450178',
#                'created_at': 'Fri Aug 27 09:33:03 +0000 2021',
#                'display_text_range': [0, 90],
#                'entities': {'hashtags': [],
#                 'symbols': [],
#                 'urls': [],
#                 'user_mentions': [{'id_str': '89784466',
#                   'indices': [3, 19],
#                   'name': 'Dr. Kari Nixon',
#                   'screen_name': 'HalfSickShadows'}]},
#                'favorite_count': 0,
#                'favorited': False,
#                'full_text': 'RT @HalfSickShadows: I just learned that hyper productivity is a trauma response and I’m 🤯',
#                'id_str': '1431187998486450178',
#                'is_quote_status': False,
#                'lang': 'en',
#                'quote_count': 0,
#                'reply_count': 0,
#                'retweet_count': 47,
#                'retweeted': False,
#                'retweeted_status_result': {'result': {'__typename': 'Tweet',
#                  'core': {'user_results': {'result': {'__typename': 'User',
#                     'affiliates_highlighted_label': {},
#                     'id': 'VXNlcjo4OTc4NDQ2Ng==',
#                     'legacy': {'created_at': 'Fri Nov 13 20:24:01 +0000 2009',
#                      'default_profile': False,
#                      'default_profile_image': False,
#                      'description': 'Asst. Prof | Medical humanities| Victorian Lit | Disease & Death | Repd by @ceciliaclyra | New book w @simonschuster https://t.co/P3HxysRmtT',
#                      'entities': {'description': {'urls': [{'display_url': 'bit.ly/QuarantineLife…',
#                          'expanded_url': 'http://bit.ly/QuarantineLifeBook',
#                          'indices': [117, 140],
#                          'url': 'https://t.co/P3HxysRmtT'}]},
#                       'url': {'urls': [{'display_url': 'mknixon.com',
#                          'expanded_url': 'http://mknixon.com',
#                          'indices': [0, 23],
#                          'url': 'https://t.co/IGk9hcrj8n'}]}},
#                      'fast_followers_count': 0,
#                      'favourites_count': 6233,
#                      'followers_count': 3398,
#                      'friends_count': 3959,
#                      'has_custom_timelines': True,
#                      'is_translator': False,
#                      'listed_count': 29,
#                      'location': 'Spokane, WA',
#                      'media_count': 587,
#                      'name': 'Dr. Kari Nixon',
#                      'normal_followers_count': 3398,
#                      'pinned_tweet_ids_str': ['1215058193446912000'],
#                      'profile_banner_extensions': {'mediaColor': {'r': {'ok': {'palette': [{'percentage': 47.44,
#                            'rgb': {'blue': 25, 'green': 50, 'red': 220}},
#                           {'percentage': 41.52,
#                            'rgb': {'blue': 255, 'green': 255, 'red': 255}},
#                           {'percentage': 4.71,
#                            'rgb': {'blue': 125, 'green': 140, 'red': 235}},
#                           {'percentage': 2.58,
#                            'rgb': {'blue': 65, 'green': 65, 'red': 215}},
#                           {'percentage': 1.96,
#                            'rgb': {'blue': 16, 'green': 29, 'red': 214}}]}}}},
#                      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/89784466/1620084749',
#                      'profile_image_extensions': {'mediaColor': {'r': {'ok': {'palette': [{'percentage': 84.95,
#                            'rgb': {'blue': 240, 'green': 241, 'red': 242}},
#                           {'percentage': 7.42,
#                            'rgb': {'blue': 27, 'green': 44, 'red': 72}},
#                           {'percentage': 4.35,
#                            'rgb': {'blue': 140, 'green': 163, 'red': 229}},
#                           {'percentage': 1.07,
#                            'rgb': {'blue': 135, 'green': 164, 'red': 209}},
#                           {'percentage': 0.38,
#                            'rgb': {'blue': 64, 'green': 79, 'red': 140}}]}}}},
#                      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1389362247651061765/0OL7WL_n_normal.jpg',
#                      'profile_interstitial_type': '',
#                      'protected': False,
#                      'screen_name': 'HalfSickShadows',
#                      'statuses_count': 6909,
#                      'translator_type': 'none',
#                      'url': 'https://t.co/IGk9hcrj8n',
#                      'verified': False,
#                      'withheld_in_countries': []},
#                     'rest_id': '89784466'}}},
#                  'legacy': {'conversation_id_str': '1430707410654556161',
#                   'created_at': 'Thu Aug 26 01:43:22 +0000 2021',
#                   'display_text_range': [0, 69],
#                   'entities': {'hashtags': [],
#                    'symbols': [],
#                    'urls': [],
#                    'user_mentions': []},
#                   'favorite_count': 455,
#                   'favorited': False,
#                   'full_text': 'I just learned that hyper productivity is a trauma response and I’m 🤯',
#                   'id_str': '1430707410654556161',
#                   'is_quote_status': False,
#                   'lang': 'en',
#                   'quote_count': 19,
#                   'reply_count': 14,
#                   'retweet_count': 47,
#                   'retweeted': False,
#                   'self_thread': {'id_str': '1430707410654556161'},
#                   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#                   'user_id_str': '89784466'},
#                  'rest_id': '1430707410654556161'}},
#                'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#                'user_id_str': '1971455317'},
#               'rest_id': '1431187998486450178'}}}},
#           'entryId': 'tweet-1431187998486450178',
#           'sortIndex': '1431187998486450178'},
#          {'content': {'entryType': 'TimelineTimelineItem',
#            'itemContent': {'itemType': 'TimelineTweet',
#             'tweetDisplayType': 'Tweet',
#             'tweet_results': {'result': {'__typename': 'Tweet',
#               'core': {'user_results': {'result': {'__typename': 'User',
#                  'affiliates_highlighted_label': {},
#                  'id': 'VXNlcjoxOTcxNDU1MzE3',
#                  'legacy': {'created_at': 'Sat Oct 19 12:11:47 +0000 2013',
#                   'default_profile': False,
#                   'default_profile_image': False,
#                   'description': 'Them. Want AI art. ex AI sfty🌻@TournesolApp, CS/Neurosci🇨🇭@EPFL_en, intern @CHAI_Berkeley, 🇺🇸@GoogleAI. Our op-s are not our own... From 🇷🇺 with ☮️❤️🌈.',
#                   'entities': {'description': {'urls': []},
#                    'url': {'urls': [{'display_url': 'sergia-ch.github.io',
#                       'expanded_url': 'https://sergia-ch.github.io',
#                       'indices': [0, 23],
#                       'url': 'https://t.co/IEhgwDqcb5'}]}},
#                   'fast_followers_count': 0,
#                   'favourites_count': 4548,
#                   'followers_count': 122,
#                   'friends_count': 1162,
#                   'has_custom_timelines': False,
#                   'is_translator': False,
#                   'listed_count': 0,
#                   'location': 'Confédération Helvétique',
#                   'media_count': 51,
#                   'name': 'Sergia',
#                   'normal_followers_count': 122,
#                   'pinned_tweet_ids_str': ['1429694898534559749'],
#                   'profile_banner_extensions': {'mediaColor': {'r': {'ok': {'palette': [{'percentage': 37.19,
#                         'rgb': {'blue': 90, 'green': 52, 'red': 47}},
#                        {'percentage': 31.4,
#                         'rgb': {'blue': 29, 'green': 24, 'red': 28}},
#                        {'percentage': 11.83,
#                         'rgb': {'blue': 171, 'green': 127, 'red': 133}},
#                        {'percentage': 8.12,
#                         'rgb': {'blue': 125, 'green': 114, 'red': 16}},
#                        {'percentage': 2.73,
#                         'rgb': {'blue': 190, 'green': 137, 'red': 36}}]}}}},
#                   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1971455317/1627655221',
#                   'profile_image_extensions': {'mediaColor': {'r': {'ok': {'palette': [{'percentage': 42.94,
#                         'rgb': {'blue': 17, 'green': 16, 'red': 22}},
#                        {'percentage': 34.25,
#                         'rgb': {'blue': 231, 'green': 247, 'red': 246}},
#                        {'percentage': 9.47,
#                         'rgb': {'blue': 95, 'green': 121, 'red': 160}},
#                        {'percentage': 4.58,
#                         'rgb': {'blue': 52, 'green': 38, 'red': 31}},
#                        {'percentage': 0.85,
#                         'rgb': {'blue': 165, 'green': 215, 'red': 243}}]}}}},
#                   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1429064209443196932/397bcCUf_normal.jpg',
#                   'profile_interstitial_type': '',
#                   'protected': False,
#                   'screen_name': 'sergeivolodinch',
#                   'statuses_count': 437,
#                   'translator_type': 'none',
#                   'url': 'https://t.co/IEhgwDqcb5',
#                   'verified': False,
#                   'withheld_in_countries': []},
#                  'rest_id': '1971455317'}}},
#               'legacy': {'conversation_id_str': '1430235822561939466',
#                'created_at': 'Wed Aug 25 17:42:29 +0000 2021',
#                'display_text_range': [10, 132],
#                'entities': {'hashtags': [],
#                 'symbols': [],
#                 'urls': [],
#                 'user_mentions': [{'id_str': '240315418',
#                   'indices': [0, 9],
#                   'name': 'саша лу',
#                   'screen_name': 'sashalu_'}]},
#                'favorite_count': 0,
#                'favorited': False,
#                'full_text': '@sashalu_ Просто заговорить об этом сложно в первый раз, это просто первый шаг, потом можно и вопрос задать :) (персонал экспериенс)',
#                'id_str': '1430586391319154692',
#                'in_reply_to_screen_name': 'sashalu_',
#                'in_reply_to_status_id_str': '1430236032168079368',
#                'in_reply_to_user_id_str': '240315418',
#                'is_quote_status': False,
#                'lang': 'ru',
#                'quote_count': 0,
#                'reply_count': 0,
#                'retweet_count': 0,
#                'retweeted': False,
#                'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#                'user_id_str': '1971455317'},
#               'rest_id': '1430586391319154692'}}}},
#           'entryId': 'tweet-1430586391319154692',
#           'sortIndex': '1430586391319154692'},
#          {'content': {'entryType': 'TimelineTimelineItem',
#            'itemContent': {'itemType': 'TimelineTweet',
#             'tweetDisplayType': 'Tweet',
#             'tweet_results': {'result': {'__typename': 'Tweet',
#               'core': {'user_results': {'result': {'__typename': 'User',
#                  'affiliates_highlighted_label': {},
#                  'id': 'VXNlcjoxOTcxNDU1MzE3',
#                  'legacy': {'created_at': 'Sat Oct 19 12:11:47 +0000 2013',
#                   'default_profile': False,
#                   'default_profile_image': False,
#                   'description': 'Them. Want AI art. ex AI sfty🌻@TournesolApp, CS/Neurosci🇨🇭@EPFL_en, intern @CHAI_Berkeley, 🇺🇸@GoogleAI. Our op-s are not our own... From 🇷🇺 with ☮️❤️🌈.',
#                   'entities': {'description': {'urls': []},
#                    'url': {'urls': [{'display_url': 'sergia-ch.github.io',
#                       'expanded_url': 'https://sergia-ch.github.io',
#                       'indices': [0, 23],
#                       'url': 'https://t.co/IEhgwDqcb5'}]}},
#                   'fast_followers_count': 0,
#                   'favourites_count': 4548,
#                   'followers_count': 122,
#                   'friends_count': 1162,
#                   'has_custom_timelines': False,
#                   'is_translator': False,
#                   'listed_count': 0,
#                   'location': 'Confédération Helvétique',
#                   'media_count': 51,
#                   'name': 'Sergia',
#                   'normal_followers_count': 122,
#                   'pinned_tweet_ids_str': ['1429694898534559749'],
#                   'profile_banner_extensions': {'mediaColor': {'r': {'ok': {'palette': [{'percentage': 37.19,
#                         'rgb': {'blue': 90, 'green': 52, 'red': 47}},
#                        {'percentage': 31.4,
#                         'rgb': {'blue': 29, 'green': 24, 'red': 28}},
#                        {'percentage': 11.83,
#                         'rgb': {'blue': 171, 'green': 127, 'red': 133}},
#                        {'percentage': 8.12,
#                         'rgb': {'blue': 125, 'green': 114, 'red': 16}},
#                        {'percentage': 2.73,
#                         'rgb': {'blue': 190, 'green': 137, 'red': 36}}]}}}},
#                   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1971455317/1627655221',
#                   'profile_image_extensions': {'mediaColor': {'r': {'ok': {'palette': [{'percentage': 42.94,
#                         'rgb': {'blue': 17, 'green': 16, 'red': 22}},
#                        {'percentage': 34.25,
#                         'rgb': {'blue': 231, 'green': 247, 'red': 246}},
#                        {'percentage': 9.47,
#                         'rgb': {'blue': 95, 'green': 121, 'red': 160}},
#                        {'percentage': 4.58,
#                         'rgb': {'blue': 52, 'green': 38, 'red': 31}},
#                        {'percentage': 0.85,
#                         'rgb': {'blue': 165, 'green': 215, 'red': 243}}]}}}},
#                   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1429064209443196932/397bcCUf_normal.jpg',
#                   'profile_interstitial_type': '',
#                   'protected': False,
#                   'screen_name': 'sergeivolodinch',
#                   'statuses_count': 437,
#                   'translator_type': 'none',
#                   'url': 'https://t.co/IEhgwDqcb5',
#                   'verified': False,
#                   'withheld_in_countries': []},
#                  'rest_id': '1971455317'}}},
#               'legacy': {'conversation_id_str': '1430539620547170306',
#                'created_at': 'Wed Aug 25 14:41:47 +0000 2021',
#                'display_text_range': [15, 87],
#                'entities': {'hashtags': [],
#                 'symbols': [],
#                 'urls': [],
#                 'user_mentions': [{'id_str': '335405374',
#                   'indices': [0, 14],
#                   'name': 'госпожа настя цой',
#                   'screen_name': 'anastaciatsoy'}]},
#                'favorite_count': 0,
#                'favorited': False,
#                'full_text': '@anastaciatsoy Нет, пиши ещё и мы все в тебя верим, ну я по крайней мере ☮️❤️🌈🦄✨🐈💃🛀🍫🍷🎸🎵',
#                'id_str': '1430540917753143303',
#                'in_reply_to_screen_name': 'anastaciatsoy',
#                'in_reply_to_status_id_str': '1430539620547170306',
#                'in_reply_to_user_id_str': '335405374',
#                'is_quote_status': False,
#                'lang': 'ru',
#                'quote_count': 0,
#                'reply_count': 0,
#                'retweet_count': 0,
#                'retweeted': False,
#                'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#                'user_id_str': '1971455317'},
#               'rest_id': '1430540917753143303'}}}},
#           'entryId': 'tweet-1430540917753143303',
#           'sortIndex': '1430540917753143303'},
#          {'content': {'entryType': 'TimelineTimelineItem',
#            'itemContent': {'itemType': 'TimelineTweet',
#             'tweetDisplayType': 'Tweet',
#             'tweet_results': {'result': {'__typename': 'Tweet',
#               'core': {'user_results': {'result': {'__typename': 'User',
#                  'affiliates_highlighted_label': {},
#                  'id': 'VXNlcjoxOTcxNDU1MzE3',
#                  'legacy': {'created_at': 'Sat Oct 19 12:11:47 +0000 2013',
#                   'default_profile': False,
#                   'default_profile_image': False,
#                   'description': 'Them. Want AI art. ex AI sfty🌻@TournesolApp, CS/Neurosci🇨🇭@EPFL_en, intern @CHAI_Berkeley, 🇺🇸@GoogleAI. Our op-s are not our own... From 🇷🇺 with ☮️❤️🌈.',
#                   'entities': {'description': {'urls': []},
#                    'url': {'urls': [{'display_url': 'sergia-ch.github.io',
#                       'expanded_url': 'https://sergia-ch.github.io',
#                       'indices': [0, 23],
#                       'url': 'https://t.co/IEhgwDqcb5'}]}},
#                   'fast_followers_count': 0,
#                   'favourites_count': 4548,
#                   'followers_count': 122,
#                   'friends_count': 1162,
#                   'has_custom_timelines': False,
#                   'is_translator': False,
#                   'listed_count': 0,
#                   'location': 'Confédération Helvétique',
#                   'media_count': 51,
#                   'name': 'Sergia',
#                   'normal_followers_count': 122,
#                   'pinned_tweet_ids_str': ['1429694898534559749'],
#                   'profile_banner_extensions': {'mediaColor': {'r': {'ok': {'palette': [{'percentage': 37.19,
#                         'rgb': {'blue': 90, 'green': 52, 'red': 47}},
#                        {'percentage': 31.4,
#                         'rgb': {'blue': 29, 'green': 24, 'red': 28}},
#                        {'percentage': 11.83,
#                         'rgb': {'blue': 171, 'green': 127, 'red': 133}},
#                        {'percentage': 8.12,
#                         'rgb': {'blue': 125, 'green': 114, 'red': 16}},
#                        {'percentage': 2.73,
#                         'rgb': {'blue': 190, 'green': 137, 'red': 36}}]}}}},
#                   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1971455317/1627655221',
#                   'profile_image_extensions': {'mediaColor': {'r': {'ok': {'palette': [{'percentage': 42.94,
#                         'rgb': {'blue': 17, 'green': 16, 'red': 22}},
#                        {'percentage': 34.25,
#                         'rgb': {'blue': 231, 'green': 247, 'red': 246}},
#                        {'percentage': 9.47,
#                         'rgb': {'blue': 95, 'green': 121, 'red': 160}},
#                        {'percentage': 4.58,
#                         'rgb': {'blue': 52, 'green': 38, 'red': 31}},
#                        {'percentage': 0.85,
#                         'rgb': {'blue': 165, 'green': 215, 'red': 243}}]}}}},
#                   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1429064209443196932/397bcCUf_normal.jpg',
#                   'profile_interstitial_type': '',
#                   'protected': False,
#                   'screen_name': 'sergeivolodinch',
#                   'statuses_count': 437,
#                   'translator_type': 'none',
#                   'url': 'https://t.co/IEhgwDqcb5',
#                   'verified': False,
#                   'withheld_in_countries': []},
#                  'rest_id': '1971455317'}}},
#               'legacy': {'conversation_id_str': '1429858134772834305',
#                'created_at': 'Wed Aug 25 10:28:38 +0000 2021',
#                'display_text_range': [26, 251],
#                'entities': {'hashtags': [],
#                 'symbols': [],
#                 'urls': [],
#                 'user_mentions': [{'id_str': '1125849026308575239',
#                   'indices': [0, 15],
#                   'name': 'Stella Rose Biderman',
#                   'screen_name': 'BlancheMinerva'},
#                  {'id_str': '33838201',
#                   'indices': [16, 25],
#                   'name': 'Google AI',
#                   'screen_name': 'GoogleAI'}]},
#                'favorite_count': 0,
#                'favorited': False,
#                'full_text': '@BlancheMinerva @GoogleAI ++++ even lawyers and policymakers don\'t know about these things. Claims like "this could be written by AI" make one sound crazy... How can democracy happen if the ones affected don\'t even know what is affecting them... ☮️❤️✨',
#                'id_str': '1430477211342151687',
#                'in_reply_to_screen_name': 'BlancheMinerva',
#                'in_reply_to_status_id_str': '1429867649186598912',
#                'in_reply_to_user_id_str': '1125849026308575239',
#                'is_quote_status': False,
#                'lang': 'en',
#                'quote_count': 0,
#                'reply_count': 0,
#                'retweet_count': 0,
#                'retweeted': False,
#                'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#                'user_id_str': '1971455317'},
#               'rest_id': '1430477211342151687'}}}},
#           'entryId': 'tweet-1430477211342151687',
#           'sortIndex': '1430477211342151687'},
#          {'content': {'entryType': 'TimelineTimelineItem',
#            'itemContent': {'itemType': 'TimelineTweet',
#             'tweetDisplayType': 'Tweet',
#             'tweet_results': {'result': {'__typename': 'Tweet',
#               'core': {'user_results': {'result': {'__typename': 'User',
#                  'affiliates_highlighted_label': {},
#                  'id': 'VXNlcjoxOTcxNDU1MzE3',
#                  'legacy': {'created_at': 'Sat Oct 19 12:11:47 +0000 2013',
#                   'default_profile': False,
#                   'default_profile_image': False,
#                   'description': 'Them. Want AI art. ex AI sfty🌻@TournesolApp, CS/Neurosci🇨🇭@EPFL_en, intern @CHAI_Berkeley, 🇺🇸@GoogleAI. Our op-s are not our own... From 🇷🇺 with ☮️❤️🌈.',
#                   'entities': {'description': {'urls': []},
#                    'url': {'urls': [{'display_url': 'sergia-ch.github.io',
#                       'expanded_url': 'https://sergia-ch.github.io',
#                       'indices': [0, 23],
#                       'url': 'https://t.co/IEhgwDqcb5'}]}},
#                   'fast_followers_count': 0,
#                   'favourites_count': 4548,
#                   'followers_count': 122,
#                   'friends_count': 1162,
#                   'has_custom_timelines': False,
#                   'is_translator': False,
#                   'listed_count': 0,
#                   'location': 'Confédération Helvétique',
#                   'media_count': 51,
#                   'name': 'Sergia',
#                   'normal_followers_count': 122,
#                   'pinned_tweet_ids_str': ['1429694898534559749'],
#                   'profile_banner_extensions': {'mediaColor': {'r': {'ok': {'palette': [{'percentage': 37.19,
#                         'rgb': {'blue': 90, 'green': 52, 'red': 47}},
#                        {'percentage': 31.4,
#                         'rgb': {'blue': 29, 'green': 24, 'red': 28}},
#                        {'percentage': 11.83,
#                         'rgb': {'blue': 171, 'green': 127, 'red': 133}},
#                        {'percentage': 8.12,
#                         'rgb': {'blue': 125, 'green': 114, 'red': 16}},
#                        {'percentage': 2.73,
#                         'rgb': {'blue': 190, 'green': 137, 'red': 36}}]}}}},
#                   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1971455317/1627655221',
#                   'profile_image_extensions': {'mediaColor': {'r': {'ok': {'palette': [{'percentage': 42.94,
#                         'rgb': {'blue': 17, 'green': 16, 'red': 22}},
#                        {'percentage': 34.25,
#                         'rgb': {'blue': 231, 'green': 247, 'red': 246}},
#                        {'percentage': 9.47,
#                         'rgb': {'blue': 95, 'green': 121, 'red': 160}},
#                        {'percentage': 4.58,
#                         'rgb': {'blue': 52, 'green': 38, 'red': 31}},
#                        {'percentage': 0.85,
#                         'rgb': {'blue': 165, 'green': 215, 'red': 243}}]}}}},
#                   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1429064209443196932/397bcCUf_normal.jpg',
#                   'profile_interstitial_type': '',
#                   'protected': False,
#                   'screen_name': 'sergeivolodinch',
#                   'statuses_count': 437,
#                   'translator_type': 'none',
#                   'url': 'https://t.co/IEhgwDqcb5',
#                   'verified': False,
#                   'withheld_in_countries': []},
#                  'rest_id': '1971455317'}}},
#               'legacy': {'conversation_id_str': '1429572662418944003',
#                'created_at': 'Mon Aug 23 10:43:01 +0000 2021',
#                'display_text_range': [6, 208],
#                'entities': {'hashtags': [],
#                 'symbols': [],
#                 'urls': [],
#                 'user_mentions': [{'id_str': '579336570',
#                   'indices': [0, 5],
#                   'name': 'Arshavir',
#                   'screen_name': '__wi'}]},
#                'favorite_count': 1,
#                'favorited': False,
#                'full_text': '@__wi Well, people do it, so it probably at least locally feels good... Would be excited if there was a study as well, especially if phrased in terms of a "cost-benefit" analysis for the one taking alcohol :)',
#                'id_str': '1429756054380896270',
#                'in_reply_to_screen_name': '__wi',
#                'in_reply_to_status_id_str': '1429572865196765198',
#                'in_reply_to_user_id_str': '579336570',
#                'is_quote_status': False,
#                'lang': 'en',
#                'quote_count': 0,
#                'reply_count': 0,
#                'retweet_count': 0,
#                'retweeted': False,
#                'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#                'user_id_str': '1971455317'},
#               'rest_id': '1429756054380896270'}}}},
#           'entryId': 'tweet-1429756054380896270',
#           'sortIndex': '1429756054380896270'},
#          {'content': {'entryType': 'TimelineTimelineItem',
#            'itemContent': {'itemType': 'TimelineTweet',
#             'tweetDisplayType': 'Tweet',
#             'tweet_results': {'result': {'__typename': 'Tweet',
#               'card': {'legacy': {'binding_values': [{'key': 'choice1_label',
#                   'value': {'string_value': 'This account is real',
#                    'type': 'STRING'}},
#                  {'key': 'choice2_label',
#                   'value': {'string_value': 'This account is fake',
#                    'type': 'STRING'}},
#                  {'key': 'end_datetime_utc',
#                   'value': {'string_value': '2021-08-30T06:38:45Z',
#                    'type': 'STRING'}},
#                  {'key': 'counts_are_final',
#                   'value': {'boolean_value': True, 'type': 'BOOLEAN'}},
#                  {'key': 'choice2_count',
#                   'value': {'string_value': '0', 'type': 'STRING'}},
#                  {'key': 'choice1_count',
#                   'value': {'string_value': '3', 'type': 'STRING'}},
#                  {'key': 'last_updated_datetime_utc',
#                   'value': {'string_value': '2021-08-30T06:38:47Z',
#                    'type': 'STRING'}},
#                  {'key': 'duration_minutes',
#                   'value': {'string_value': '10080', 'type': 'STRING'}},
#                  {'key': 'api',
#                   'value': {'string_value': 'capi://passthrough/1',
#                    'type': 'STRING'}},
#                  {'key': 'card_url',
#                   'value': {'scribe_key': 'card_url',
#                    'string_value': 'https://twitter.com',
#                    'type': 'STRING'}}],
#                 'card_platform': {'platform': {'audience': {'name': 'production'},
#                   'device': {'name': 'Swift', 'version': '12'}}},
#                 'name': 'poll2choice_text_only',
#                 'url': 'card://1429694581969461248',
#                 'user_refs': []},
#                'rest_id': 'card://1429694581969461248'},
#               'core': {'user_results': {'result': {'__typename': 'User',
#                  'affiliates_highlighted_label': {},
#                  'id': 'VXNlcjoxOTcxNDU1MzE3',
#                  'legacy': {'created_at': 'Sat Oct 19 12:11:47 +0000 2013',
#                   'default_profile': False,
#                   'default_profile_image': False,
#                   'description': 'Them. Want AI art. ex AI sfty🌻@TournesolApp, CS/Neurosci🇨🇭@EPFL_en, intern @CHAI_Berkeley, 🇺🇸@GoogleAI. Our op-s are not our own... From 🇷🇺 with ☮️❤️🌈.',
#                   'entities': {'description': {'urls': []},
#                    'url': {'urls': [{'display_url': 'sergia-ch.github.io',
#                       'expanded_url': 'https://sergia-ch.github.io',
#                       'indices': [0, 23],
#                       'url': 'https://t.co/IEhgwDqcb5'}]}},
#                   'fast_followers_count': 0,
#                   'favourites_count': 4548,
#                   'followers_count': 122,
#                   'friends_count': 1162,
#                   'has_custom_timelines': False,
#                   'is_translator': False,
#                   'listed_count': 0,
#                   'location': 'Confédération Helvétique',
#                   'media_count': 51,
#                   'name': 'Sergia',
#                   'normal_followers_count': 122,
#                   'pinned_tweet_ids_str': ['1429694898534559749'],
#                   'profile_banner_extensions': {'mediaColor': {'r': {'ok': {'palette': [{'percentage': 37.19,
#                         'rgb': {'blue': 90, 'green': 52, 'red': 47}},
#                        {'percentage': 31.4,
#                         'rgb': {'blue': 29, 'green': 24, 'red': 28}},
#                        {'percentage': 11.83,
#                         'rgb': {'blue': 171, 'green': 127, 'red': 133}},
#                        {'percentage': 8.12,
#                         'rgb': {'blue': 125, 'green': 114, 'red': 16}},
#                        {'percentage': 2.73,
#                         'rgb': {'blue': 190, 'green': 137, 'red': 36}}]}}}},
#                   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1971455317/1627655221',
#                   'profile_image_extensions': {'mediaColor': {'r': {'ok': {'palette': [{'percentage': 42.94,
#                         'rgb': {'blue': 17, 'green': 16, 'red': 22}},
#                        {'percentage': 34.25,
#                         'rgb': {'blue': 231, 'green': 247, 'red': 246}},
#                        {'percentage': 9.47,
#                         'rgb': {'blue': 95, 'green': 121, 'red': 160}},
#                        {'percentage': 4.58,
#                         'rgb': {'blue': 52, 'green': 38, 'red': 31}},
#                        {'percentage': 0.85,
#                         'rgb': {'blue': 165, 'green': 215, 'red': 243}}]}}}},
#                   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1429064209443196932/397bcCUf_normal.jpg',
#                   'profile_interstitial_type': '',
#                   'protected': False,
#                   'screen_name': 'sergeivolodinch',
#                   'statuses_count': 437,
#                   'translator_type': 'none',
#                   'url': 'https://t.co/IEhgwDqcb5',
#                   'verified': False,
#                   'withheld_in_countries': []},
#                  'rest_id': '1971455317'}}},
#               'legacy': {'conversation_id_str': '1429694583185809408',
#                'created_at': 'Mon Aug 23 06:38:45 +0000 2021',
#                'display_text_range': [0, 231],
#                'entities': {'hashtags': [],
#                 'symbols': [],
#                 'urls': [],
#                 'user_mentions': []},
#                'favorite_count': 0,
#                'favorited': False,
#                'full_text': 'I often write about somewhat controversial / polarising topics. My intention is to have a chill discussion to merge the filter bubbles. Do you think my account is fake or real? Do my tweets correspond to my intention from your POV?',
#                'id_str': '1429694583185809408',
#                'is_quote_status': False,
#                'lang': 'en',
#                'possibly_sensitive': False,
#                'possibly_sensitive_editable': True,
#                'quote_count': 0,
#                'reply_count': 1,
#                'retweet_count': 0,
#                'retweeted': False,
#                'self_thread': {'id_str': '1429694583185809408'},
#                'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#                'user_id_str': '1971455317'},
#               'rest_id': '1429694583185809408'}}}},
#           'entryId': 'tweet-1429694583185809408',
#           'sortIndex': '1429694583185809408'},
#          {'content': {'entryType': 'TimelineTimelineItem',
#            'itemContent': {'itemType': 'TimelineTweet',
#             'tweetDisplayType': 'Tweet',
#             'tweet_results': {'result': {'__typename': 'Tweet',
#               'core': {'user_results': {'result': {'__typename': 'User',
#                  'affiliates_highlighted_label': {},
#                  'id': 'VXNlcjoxOTcxNDU1MzE3',
#                  'legacy': {'created_at': 'Sat Oct 19 12:11:47 +0000 2013',
#                   'default_profile': False,
#                   'default_profile_image': False,
#                   'description': 'Them. Want AI art. ex AI sfty🌻@TournesolApp, CS/Neurosci🇨🇭@EPFL_en, intern @CHAI_Berkeley, 🇺🇸@GoogleAI. Our op-s are not our own... From 🇷🇺 with ☮️❤️🌈.',
#                   'entities': {'description': {'urls': []},
#                    'url': {'urls': [{'display_url': 'sergia-ch.github.io',
#                       'expanded_url': 'https://sergia-ch.github.io',
#                       'indices': [0, 23],
#                       'url': 'https://t.co/IEhgwDqcb5'}]}},
#                   'fast_followers_count': 0,
#                   'favourites_count': 4548,
#                   'followers_count': 122,
#                   'friends_count': 1162,
#                   'has_custom_timelines': False,
#                   'is_translator': False,
#                   'listed_count': 0,
#                   'location': 'Confédération Helvétique',
#                   'media_count': 51,
#                   'name': 'Sergia',
#                   'normal_followers_count': 122,
#                   'pinned_tweet_ids_str': ['1429694898534559749'],
#                   'profile_banner_extensions': {'mediaColor': {'r': {'ok': {'palette': [{'percentage': 37.19,
#                         'rgb': {'blue': 90, 'green': 52, 'red': 47}},
#                        {'percentage': 31.4,
#                         'rgb': {'blue': 29, 'green': 24, 'red': 28}},
#                        {'percentage': 11.83,
#                         'rgb': {'blue': 171, 'green': 127, 'red': 133}},
#                        {'percentage': 8.12,
#                         'rgb': {'blue': 125, 'green': 114, 'red': 16}},
#                        {'percentage': 2.73,
#                         'rgb': {'blue': 190, 'green': 137, 'red': 36}}]}}}},
#                   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1971455317/1627655221',
#                   'profile_image_extensions': {'mediaColor': {'r': {'ok': {'palette': [{'percentage': 42.94,
#                         'rgb': {'blue': 17, 'green': 16, 'red': 22}},
#                        {'percentage': 34.25,
#                         'rgb': {'blue': 231, 'green': 247, 'red': 246}},
#                        {'percentage': 9.47,
#                         'rgb': {'blue': 95, 'green': 121, 'red': 160}},
#                        {'percentage': 4.58,
#                         'rgb': {'blue': 52, 'green': 38, 'red': 31}},
#                        {'percentage': 0.85,
#                         'rgb': {'blue': 165, 'green': 215, 'red': 243}}]}}}},
#                   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1429064209443196932/397bcCUf_normal.jpg',
#                   'profile_interstitial_type': '',
#                   'protected': False,
#                   'screen_name': 'sergeivolodinch',
#                   'statuses_count': 437,
#                   'translator_type': 'none',
#                   'url': 'https://t.co/IEhgwDqcb5',
#                   'verified': False,
#                   'withheld_in_countries': []},
#                  'rest_id': '1971455317'}}},
#               'legacy': {'conversation_id_str': '1425913036368343044',
#                'created_at': 'Mon Aug 23 06:22:36 +0000 2021',
#                'display_text_range': [36, 105],
#                'entities': {'hashtags': [],
#                 'symbols': [],
#                 'urls': [],
#                 'user_mentions': [{'id_str': '30380195',
#                   'indices': [0, 13],
#                   'name': 'Ruth Starkman',
#                   'screen_name': 'ruthstarkman'},
#                  {'id_str': '78012548',
#                   'indices': [14, 26],
#                   'name': 'The Register',
#                   'screen_name': 'TheRegister'},
#                  {'id_str': '783214',
#                   'indices': [27, 35],
#                   'name': 'Twitter',
#                   'screen_name': 'Twitter'}]},
#                'favorite_count': 0,
#                'favorited': False,
#                'full_text': "@ruthstarkman @TheRegister @Twitter (I'm getting some weird likes, and no answer, deleting all this soon)",
#                'id_str': '1429690516464148485',
#                'in_reply_to_screen_name': 'sergeivolodinch',
#                'in_reply_to_status_id_str': '1426040400586936320',
#                'in_reply_to_user_id_str': '1971455317',
#                'is_quote_status': False,
#                'lang': 'en',
#                'quote_count': 0,
#                'reply_count': 0,
#                'retweet_count': 0,
#                'retweeted': False,
#                'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#                'user_id_str': '1971455317'},
#               'rest_id': '1429690516464148485'}}}},
#           'entryId': 'tweet-1429690516464148485',
#           'sortIndex': '1429690516464148485'},
#          {'content': {'entryType': 'TimelineTimelineItem',
#            'itemContent': {'itemType': 'TimelineTweet',
#             'tweetDisplayType': 'Tweet',
#             'tweet_results': {'result': {'__typename': 'Tweet',
#               'core': {'user_results': {'result': {'__typename': 'User',
#                  'affiliates_highlighted_label': {},
#                  'id': 'VXNlcjoxOTcxNDU1MzE3',
#                  'legacy': {'created_at': 'Sat Oct 19 12:11:47 +0000 2013',
#                   'default_profile': False,
#                   'default_profile_image': False,
#                   'description': 'Them. Want AI art. ex AI sfty🌻@TournesolApp, CS/Neurosci🇨🇭@EPFL_en, intern @CHAI_Berkeley, 🇺🇸@GoogleAI. Our op-s are not our own... From 🇷🇺 with ☮️❤️🌈.',
#                   'entities': {'description': {'urls': []},
#                    'url': {'urls': [{'display_url': 'sergia-ch.github.io',
#                       'expanded_url': 'https://sergia-ch.github.io',
#                       'indices': [0, 23],
#                       'url': 'https://t.co/IEhgwDqcb5'}]}},
#                   'fast_followers_count': 0,
#                   'favourites_count': 4548,
#                   'followers_count': 122,
#                   'friends_count': 1162,
#                   'has_custom_timelines': False,
#                   'is_translator': False,
#                   'listed_count': 0,
#                   'location': 'Confédération Helvétique',
#                   'media_count': 51,
#                   'name': 'Sergia',
#                   'normal_followers_count': 122,
#                   'pinned_tweet_ids_str': ['1429694898534559749'],
#                   'profile_banner_extensions': {'mediaColor': {'r': {'ok': {'palette': [{'percentage': 37.19,
#                         'rgb': {'blue': 90, 'green': 52, 'red': 47}},
#                        {'percentage': 31.4,
#                         'rgb': {'blue': 29, 'green': 24, 'red': 28}},
#                        {'percentage': 11.83,
#                         'rgb': {'blue': 171, 'green': 127, 'red': 133}},
#                        {'percentage': 8.12,
#                         'rgb': {'blue': 125, 'green': 114, 'red': 16}},
#                        {'percentage': 2.73,
#                         'rgb': {'blue': 190, 'green': 137, 'red': 36}}]}}}},
#                   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1971455317/1627655221',
#                   'profile_image_extensions': {'mediaColor': {'r': {'ok': {'palette': [{'percentage': 42.94,
#                         'rgb': {'blue': 17, 'green': 16, 'red': 22}},
#                        {'percentage': 34.25,
#                         'rgb': {'blue': 231, 'green': 247, 'red': 246}},
#                        {'percentage': 9.47,
#                         'rgb': {'blue': 95, 'green': 121, 'red': 160}},
#                        {'percentage': 4.58,
#                         'rgb': {'blue': 52, 'green': 38, 'red': 31}},
#                        {'percentage': 0.85,
#                         'rgb': {'blue': 165, 'green': 215, 'red': 243}}]}}}},
#                   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1429064209443196932/397bcCUf_normal.jpg',
#                   'profile_interstitial_type': '',
#                   'protected': False,
#                   'screen_name': 'sergeivolodinch',
#                   'statuses_count': 437,
#                   'translator_type': 'none',
#                   'url': 'https://t.co/IEhgwDqcb5',
#                   'verified': False,
#                   'withheld_in_countries': []},
#                  'rest_id': '1971455317'}}},
#               'legacy': {'conversation_id_str': '1429154283640000516',
#                'created_at': 'Sat Aug 21 18:51:48 +0000 2021',
#                'display_text_range': [0, 140],
#                'entities': {'hashtags': [],
#                 'symbols': [],
#                 'urls': [],
#                 'user_mentions': []},
#                'favorite_count': 0,
#                'favorited': False,
#                'full_text': 'RT @TheMentalBreak: Wishing the worst for someone actually says more about your inner world than anything else.\n\nDrop the spite, drop reven…',
#                'id_str': '1429154283640000516',
#                'is_quote_status': False,
#                'lang': 'en',
#                'quote_count': 0,
#                'reply_count': 0,
#                'retweet_count': 125,
#                'retweeted': False,
#                'retweeted_status_result': {'result': {'__typename': 'Tweet',
#                  'core': {'user_results': {'result': {'__typename': 'User',
#                     'affiliates_highlighted_label': {},
#                     'id': 'VXNlcjo5OTQ4Njc0NTgxODI5MTgxNDQ=',
#                     'legacy': {'created_at': 'Fri May 11 09:11:00 +0000 2018',
#                      'default_profile': True,
#                      'default_profile_image': False,
#                      'description': '🔥I help you shed fat and keep it off | 📲 bus enquiries: chris@coachchrisjones.live',
#                      'entities': {'description': {'urls': []},
#                       'url': {'urls': [{'display_url': 'cjcoaching.carrd.co',
#                          'expanded_url': 'https://cjcoaching.carrd.co/',
#                          'indices': [0, 23],
#                          'url': 'https://t.co/jEHc43fYu0'}]}},
#                      'fast_followers_count': 0,
#                      'favourites_count': 26669,
#                      'followers_count': 51712,
#                      'friends_count': 93,
#                      'has_custom_timelines': False,
#                      'is_translator': False,
#                      'listed_count': 274,
#                      'location': 'Join my newsletter →',
#                      'media_count': 71,
#                      'name': 'Chris | Online Coach',
#                      'normal_followers_count': 51712,
#                      'pinned_tweet_ids_str': ['1427319302387081221'],
#                      'profile_banner_extensions': {'mediaColor': {'r': {'ok': {'palette': [{'percentage': 82.81,
# ...
#                   'normal_followers_count': 122,
#                   'pinned_tweet_ids_str': ['1429694898534559749'],
#                   'profile_banner_extensions': {'mediaColor': {'r': {'ok': {'palette': [{'percentage': 37.19,
#                         'rgb': {'blue': 90, 'green': 52, 'red': 47}},
#                        {'percentage': 31.4,
#                         'rgb': {'blue': 29, 'green': 24, 'red': 28}},
#                        {'percentage': 11.83,
#                         'rgb': {'blue': 171, 'green': 127, 'red': 133}},
#                        {'percentage': 8.12,
#                         'rgb': {'blue': 125, 'green': 114, 'red': 16}},
#                        {'percentage': 2.73,
#                         'rgb': {'blue': 190, 'green': 137, 'red': 36}}]}}}},
#                   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1971455317/1627655221',
#                   'profile_image_extensions': {'mediaColor': {'r': {'ok': {'palette': [{'percentage': 42.94,
#                         'rgb': {'blue': 17, 'green': 16, 'red': 22}},
#                        {'percentage': 34.25,
#                         'rgb': {'blue': 231, 'green': 247, 'red': 246}},
#                        {'percentage': 9.47,
#                         'rgb': {'blue': 95, 'green': 121, 'red': 160}},
#                        {'percentage': 4.58,
#                         'rgb': {'blue': 52, 'green': 38, 'red': 31}},
#                        {'percentage': 0.85,
#                         'rgb': {'blue': 165, 'green': 215, 'red': 243}}]}}}},
#                   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1429064209443196932/397bcCUf_normal.jpg',
#                   'profile_interstitial_type': '',
#                   'protected': False,
#                   'screen_name': 'sergeivolodinch',
#                   'statuses_count': 437,
#                   'translator_type': 'none',
#                   'url': 'https://t.co/IEhgwDqcb5',
#                   'verified': False,
#                   'withheld_in_countries': []},
#                  'rest_id': '1971455317'}}},
#               'legacy': {'conversation_id_str': '1428935281667756033',
#                'created_at': 'Sat Aug 21 12:58:14 +0000 2021',
#                'display_text_range': [13, 15],
#                'entities': {'hashtags': [],
#                 'symbols': [],
#                 'urls': [],
#                 'user_mentions': [{'id_str': '282948199',
#                   'indices': [0, 12],
#                   'name': 'Andrés Gómez Emilsson',
#                   'screen_name': 'algekalipso'}]},
#                'favorite_count': 1,
#                'favorited': False,
#                'full_text': '@algekalipso ❤️',
#                'id_str': '1429065305142214660',
#                'in_reply_to_screen_name': 'algekalipso',
#                'in_reply_to_status_id_str': '1428935281667756033',
#                'in_reply_to_user_id_str': '282948199',
#                'is_quote_status': False,
#                'lang': 'und',
#                'quote_count': 0,
#                'reply_count': 0,
#                'retweet_count': 0,
#                'retweeted': False,
#                'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#                'user_id_str': '1971455317'},
#               'rest_id': '1429065305142214660'}}}},
#           'entryId': 'tweet-1429065305142214660',
#           'sortIndex': '1429065305142214660'},
#          {'content': {'entryType': 'TimelineTimelineItem',
#            'itemContent': {'itemType': 'TimelineTweet',
#             'tweetDisplayType': 'Tweet',
#             'tweet_results': {'result': {'__typename': 'Tweet',
#               'core': {'user_results': {'result': {'__typename': 'User',
#                  'affiliates_highlighted_label': {},
#                  'id': 'VXNlcjoxOTcxNDU1MzE3',
#                  'legacy': {'created_at': 'Sat Oct 19 12:11:47 +0000 2013',
#                   'default_profile': False,
#                   'default_profile_image': False,
#                   'description': 'Them. Want AI art. ex AI sfty🌻@TournesolApp, CS/Neurosci🇨🇭@EPFL_en, intern @CHAI_Berkeley, 🇺🇸@GoogleAI. Our op-s are not our own... From 🇷🇺 with ☮️❤️🌈.',
#                   'entities': {'description': {'urls': []},
#                    'url': {'urls': [{'display_url': 'sergia-ch.github.io',
#                       'expanded_url': 'https://sergia-ch.github.io',
#                       'indices': [0, 23],
#                       'url': 'https://t.co/IEhgwDqcb5'}]}},
#                   'fast_followers_count': 0,
#                   'favourites_count': 4548,
#                   'followers_count': 122,
#                   'friends_count': 1162,
#                   'has_custom_timelines': False,
#                   'is_translator': False,
#                   'listed_count': 0,
#                   'location': 'Confédération Helvétique',
#                   'media_count': 51,
#                   'name': 'Sergia',
#                   'normal_followers_count': 122,
#                   'pinned_tweet_ids_str': ['1429694898534559749'],
#                   'profile_banner_extensions': {'mediaColor': {'r': {'ok': {'palette': [{'percentage': 37.19,
#                         'rgb': {'blue': 90, 'green': 52, 'red': 47}},
#                        {'percentage': 31.4,
#                         'rgb': {'blue': 29, 'green': 24, 'red': 28}},
#                        {'percentage': 11.83,
#                         'rgb': {'blue': 171, 'green': 127, 'red': 133}},
#                        {'percentage': 8.12,
#                         'rgb': {'blue': 125, 'green': 114, 'red': 16}},
#                        {'percentage': 2.73,
#                         'rgb': {'blue': 190, 'green': 137, 'red': 36}}]}}}},
#                   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1971455317/1627655221',
#                   'profile_image_extensions': {'mediaColor': {'r': {'ok': {'palette': [{'percentage': 42.94,
#                         'rgb': {'blue': 17, 'green': 16, 'red': 22}},
#                        {'percentage': 34.25,
#                         'rgb': {'blue': 231, 'green': 247, 'red': 246}},
#                        {'percentage': 9.47,
#                         'rgb': {'blue': 95, 'green': 121, 'red': 160}},
#                        {'percentage': 4.58,
#                         'rgb': {'blue': 52, 'green': 38, 'red': 31}},
#                        {'percentage': 0.85,
#                         'rgb': {'blue': 165, 'green': 215, 'red': 243}}]}}}},
#                   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1429064209443196932/397bcCUf_normal.jpg',
#                   'profile_interstitial_type': '',
#                   'protected': False,
#                   'screen_name': 'sergeivolodinch',
#                   'statuses_count': 437,
#                   'translator_type': 'none',
#                   'url': 'https://t.co/IEhgwDqcb5',
#                   'verified': False,
#                   'withheld_in_countries': []},
#                  'rest_id': '1971455317'}}},
#               'legacy': {'conversation_id_str': '1428178213424050176',
#                'created_at': 'Thu Aug 19 06:53:38 +0000 2021',
#                'display_text_range': [24, 71],
#                'entities': {'hashtags': [],
#                 'symbols': [],
#                 'urls': [],
#                 'user_mentions': [{'id_str': '359831209',
#                   'indices': [0, 12],
#                   'name': 'Timnit Gebru',
#                   'screen_name': 'timnitGebru'},
#                  {'id_str': '144553035',
#                   'indices': [13, 23],
#                   'name': 'El Mahdi El Mhamdi - #26011 #23052',
#                   'screen_name': 'L_badikho'}]},
#                'favorite_count': 2,
#                'favorited': False,
#                'full_text': '@timnitGebru @L_badikho Let me know if you need a research assistant...',
#                'id_str': '1428248774795800576',
#                'in_reply_to_screen_name': 'timnitGebru',
#                'in_reply_to_status_id_str': '1428178213424050176',
#                'in_reply_to_user_id_str': '359831209',
#                'is_quote_status': False,
#                'lang': 'en',
#                'quote_count': 0,
#                'reply_count': 0,
#                'retweet_count': 0,
#                'retweeted': False,
#                'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#                'user_id_str': '1971455317'},
#               'rest_id': '1428248774795800576'}}}},
#           'entryId': 'tweet-1428248774795800576',
#           'sortIndex': '1428248774795800576'},
#          {'content': {'cursorType': 'Top',
#            'entryType': 'TimelineTimelineCursor',
#            'value': 'HCaAwKKluLys3ScAAA=='},
#           'entryId': 'cursor-top-1431398051944353793',
#           'sortIndex': '1431398051944353793'},
#          {'content': {'cursorType': 'Bottom',
#            'entryType': 'TimelineTimelineCursor',
#            'stopOnEmptyResponse': True,
#            'value': 'HBaAwLmJsayU0icAAA=='},
#           'entryId': 'cursor-bottom-1428248774795800575',
#           'sortIndex': '1428248774795800575'}],
#         'type': 'TimelineAddEntries'},
#        {'entry': {'content': {'clientEventInfo': {'component': 'suggest_pinned_tweet',
#            'details': {'timelinesDetails': {'injectionType': 'PinnedTweet'}}},
#           'entryType': 'TimelineTimelineItem',
#           'itemContent': {'itemType': 'TimelineTweet',
#            'socialContext': {'contextType': 'Pin',
#             'text': 'Pinned Tweet',
#             'type': 'TimelineGeneralContext'},
#            'tweetDisplayType': 'Tweet',
#            'tweet_results': {'result': {'__typename': 'Tweet',
#              'card': {'legacy': {'binding_values': [{'key': 'choice1_label',
#                  'value': {'string_value': 'Yes', 'type': 'STRING'}},
#                 {'key': 'choice2_label',
#                  'value': {'string_value': 'No', 'type': 'STRING'}},
#                 {'key': 'end_datetime_utc',
#                  'value': {'string_value': '2021-08-30T06:40:00Z',
#                   'type': 'STRING'}},
#                 {'key': 'counts_are_final',
#                  'value': {'boolean_value': True, 'type': 'BOOLEAN'}},
#                 {'key': 'choice2_count',
#                  'value': {'string_value': '1', 'type': 'STRING'}},
#                 {'key': 'choice1_count',
#                  'value': {'string_value': '0', 'type': 'STRING'}},
#                 {'key': 'last_updated_datetime_utc',
#                  'value': {'string_value': '2021-08-30T06:40:05Z',
#                   'type': 'STRING'}},
#                 {'key': 'duration_minutes',
#                  'value': {'string_value': '10080', 'type': 'STRING'}},
#                 {'key': 'api',
#                  'value': {'string_value': 'capi://passthrough/1',
#                   'type': 'STRING'}},
#                 {'key': 'card_url',
#                  'value': {'scribe_key': 'card_url',
#                   'string_value': 'https://twitter.com',
#                   'type': 'STRING'}}],
#                'card_platform': {'platform': {'audience': {'name': 'production'},
#                  'device': {'name': 'Swift', 'version': '12'}}},
#                'name': 'poll2choice_text_only',
#                'url': 'card://1429694897255288837',
#                'user_refs': []},
#               'rest_id': 'card://1429694897255288837'},
#              'core': {'user_results': {'result': {'__typename': 'User',
#                 'affiliates_highlighted_label': {},
#                 'id': 'VXNlcjoxOTcxNDU1MzE3',
#                 'legacy': {'created_at': 'Sat Oct 19 12:11:47 +0000 2013',
#                  'default_profile': False,
#                  'default_profile_image': False,
#                  'description': 'Them. Want AI art. ex AI sfty🌻@TournesolApp, CS/Neurosci🇨🇭@EPFL_en, intern @CHAI_Berkeley, 🇺🇸@GoogleAI. Our op-s are not our own... From 🇷🇺 with ☮️❤️🌈.',
#                  'entities': {'description': {'urls': []},
#                   'url': {'urls': [{'display_url': 'sergia-ch.github.io',
#                      'expanded_url': 'https://sergia-ch.github.io',
#                      'indices': [0, 23],
#                      'url': 'https://t.co/IEhgwDqcb5'}]}},
#                  'fast_followers_count': 0,
#                  'favourites_count': 4548,
#                  'followers_count': 122,
#                  'friends_count': 1162,
#                  'has_custom_timelines': False,
#                  'is_translator': False,
#                  'listed_count': 0,
#                  'location': 'Confédération Helvétique',
#                  'media_count': 51,
#                  'name': 'Sergia',
#                  'normal_followers_count': 122,
#                  'pinned_tweet_ids_str': ['1429694898534559749'],
#                  'profile_banner_extensions': {'mediaColor': {'r': {'ok': {'palette': [{'percentage': 37.19,
#                        'rgb': {'blue': 90, 'green': 52, 'red': 47}},
#                       {'percentage': 31.4,
#                        'rgb': {'blue': 29, 'green': 24, 'red': 28}},
#                       {'percentage': 11.83,
#                        'rgb': {'blue': 171, 'green': 127, 'red': 133}},
#                       {'percentage': 8.12,
#                        'rgb': {'blue': 125, 'green': 114, 'red': 16}},
#                       {'percentage': 2.73,
#                        'rgb': {'blue': 190, 'green': 137, 'red': 36}}]}}}},
#                  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1971455317/1627655221',
#                  'profile_image_extensions': {'mediaColor': {'r': {'ok': {'palette': [{'percentage': 42.94,
#                        'rgb': {'blue': 17, 'green': 16, 'red': 22}},
#                       {'percentage': 34.25,
#                        'rgb': {'blue': 231, 'green': 247, 'red': 246}},
#                       {'percentage': 9.47,
#                        'rgb': {'blue': 95, 'green': 121, 'red': 160}},
#                       {'percentage': 4.58,
#                        'rgb': {'blue': 52, 'green': 38, 'red': 31}},
#                       {'percentage': 0.85,
#                        'rgb': {'blue': 165, 'green': 215, 'red': 243}}]}}}},
#                  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1429064209443196932/397bcCUf_normal.jpg',
#                  'profile_interstitial_type': '',
#                  'protected': False,
#                  'screen_name': 'sergeivolodinch',
#                  'statuses_count': 437,
#                  'translator_type': 'none',
#                  'url': 'https://t.co/IEhgwDqcb5',
#                  'verified': False,
#                  'withheld_in_countries': []},
#                 'rest_id': '1971455317'}}},
#              'legacy': {'conversation_id_str': '1429694583185809408',
#               'created_at': 'Mon Aug 23 06:40:00 +0000 2021',
#               'display_text_range': [0, 76],
#               'entities': {'hashtags': [],
#                'symbols': [],
#                'urls': [],
#                'user_mentions': []},
#               'favorite_count': 0,
#               'favorited': False,
#               'full_text': 'My discussions generally help to chill &amp; think better about these topics',
#               'id_str': '1429694898534559749',
#               'in_reply_to_screen_name': 'sergeivolodinch',
#               'in_reply_to_status_id_str': '1429694583185809408',
#               'in_reply_to_user_id_str': '1971455317',
#               'is_quote_status': False,
#               'lang': 'en',
#               'possibly_sensitive': False,
#               'possibly_sensitive_editable': True,
#               'quote_count': 0,
#               'reply_count': 0,
#               'retweet_count': 0,
#               'retweeted': False,
#               'self_thread': {'id_str': '1429694583185809408'},
#               'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#               'user_id_str': '1971455317'},
#              'rest_id': '1429694898534559749'}}}},
#          'entryId': 'tweet-1429694898534559749',
#          'sortIndex': '1431398051944353792'},
#         'type': 'TimelinePinEntry'}],
#       'responseObjects': {'feedbackActions': []}}}}}}}
